# %%
import numpy as np
import matplotlib.pyplot as plt
import bioframe
from scipy import signal

# %%
ref_genome=bioframe.fetch_chromsizes ('mm9')

# %%
bins=bioframe.binnify(ref_genome,1000000)
bins
# Out:
#      chrom     start       end
# 0     chr1         0   1000000
# 1     chr1   1000000   2000000
# 2     chr1   2000000   3000000
# 3     chr1   3000000   4000000
# 4     chr1   4000000   5000000
# ...    ...       ...       ...
# 2661  chrY  12000000  13000000
# 2662  chrY  13000000  14000000
# 2663  chrY  14000000  15000000
# 2664  chrY  15000000  15902555
# 2665  chrM         0     16299
#
# [2666 rows x 3 columns]

# %%
print(bins.iloc[365]) #365th bin location
# Out:
# chrom         chr2
# start    167000000
# end      168000000
# Name: 365, dtype: object

# %% [markdown]
# # SINGLE CELL (1 MB Res)

# %%
contact_matrix=np.loadtxt('../GSE154353_1mb_single_cell_matrices_all/1mb_matrices_cluster/DPM6bot1.Odd2Bo1.Even2Bo61.10000.unweighted')

# %%
contact_matrix.shape
# Out:
# (2649, 2649)

# %%
#Normalize
max_value=np.max(contact_matrix)
contact_matrix=contact_matrix/max_value

# %%
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix, cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 0.4);
plt.show()

# %%
s1=1000
s2=s1
e1=1500
e2=e1
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix[s1:e1,s2:e2], cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 0.4);
plt.xlabel(bins.iloc[s1]['chrom']+" "+str(bins.iloc[s1]['start'])+" - "+bins.iloc[e1]['chrom']+" "+str(bins.iloc[e1]['end']))
plt.ylabel(bins.iloc[s2]['chrom']+" "+str(bins.iloc[s2]['start'])+" - "+bins.iloc[e2]['chrom']+" "+str(bins.iloc[e2]['end']))
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix[0:199,0:199], cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 0.4);
plt.xlabel("Chromosome 1")
plt.ylabel("Chromosome 1")
plt.show()

# %% [markdown]
# # COMBINED CELLS (1 MB)

# %%
contact_matrix=np.loadtxt("../Scripts/combined.txt")

# %%
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix, cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 3000);
plt.show()

# %%
s1=1000
s2=s1
e1=1500
e2=e1
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix[s1:e1,s2:e2], cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 3000);
plt.xlabel(bins.iloc[s1]['chrom']+" "+str(bins.iloc[s1]['start'])+" - "+bins.iloc[e1]['chrom']+" "+str(bins.iloc[e1]['end']))
plt.ylabel(bins.iloc[s2]['chrom']+" "+str(bins.iloc[s2]['start'])+" - "+bins.iloc[e2]['chrom']+" "+str(bins.iloc[e2]['end']))
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix[0:199,0:199], cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 3000);
plt.xlabel("Chromosome 1")
plt.ylabel("Chromosome 1")
plt.show()

# %% [markdown]
# ## Normalized Combined Contact Matrix (1 MB)

# %%
normalized_combined_matrix=np.loadtxt("../Scripts/combined.matrix.norm", delimiter='\t')

# %%
plt.figure(figsize=(10, 10))
plt.imshow(normalized_combined_matrix, cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 2000);
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(normalized_combined_matrix[0:199,0:199], cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
plt.clim(0, 3000);
plt.xlabel("Chromosome 1")
plt.ylabel("Chromosome 1")
plt.show()

# %% [markdown]
# # Single Cells (40 KB)

# %%
contact_matrix_4OKB=np.loadtxt("../GSE154353_40kb_single_cell_matrices_all/DPM6bot69.Odd2Bo2.Even2Bo66.chr4.10000.matrix")

# %%
plt.figure(figsize=(10, 10))
plt.imshow(contact_matrix_4OKB, cmap='hot', interpolation='nearest')
plt.colorbar(extend='both')
#plt.clim(0, 0.0009);
plt.xlabel("Chromosome 4")
plt.ylabel("Chromosome 4")
plt.show()
